# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from statistics import median
from statistics import mean
from statistics import harmonic_mean
import cv2

# %%
import sys
eps = sys.float_info.epsilon

# %%
from statistics import geometric_mean

# %%
loc = 'C:/Users/sherw/OneDrive/Desktop/DIP_HW4/inputs/1-1.png'
image = np.array(Image.open(loc).convert('L'))

# %%
def pix_med_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = median(neigh_pixs)
    return out_pixel
def median_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_med_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_midpoint_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = 1/2*(max(neigh_pixs)+min(neigh_pixs))
    return out_pixel
def midpoint_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_midpoint_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_max_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = max(neigh_pixs)
    return out_pixel
def max_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_max_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_min_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = min(neigh_pixs)
    return out_pixel
def min_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_min_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_arithmetic_mean_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = mean(neigh_pixs)
    return out_pixel
def arithmetic_mean_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_arithmetic_mean_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_geometric_mean_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    if 0 in neigh_pixs:
        out_pixel = 0
    else:
        out_pixel = geometric_mean(neigh_pixs)
    return out_pixel
def geometric_mean_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_geometric_mean_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_harmonic_mean_filter(pixelcoor, image2, filtershape):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    out_pixel = harmonic_mean(neigh_pixs)
    return out_pixel
def harmonic_mean_filter(image,filter_size):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_harmonic_mean_filter([i,j], image, filter_size)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %%
def pix_contraharmonic_mean_filter(pixelcoor, image2, filtershape,Q):
    size = list(range(-filtershape//2+1,filtershape//2+1))
    a, b = pixelcoor
    z, w = image2.shape
    neigh_pixs = []
    for col in size:
        for row in size:
            if 0 <= a + row < z and 0 <= b + col < w:
                neigh_pixs.append(image2[a+row,b+col])
    neigh_pixs = np.array(neigh_pixs).astype(np.float)
    if Q>=0:
        out_pixel = np.sum(neigh_pixs**(Q+1)) / (np.sum(neigh_pixs**(Q))+eps)
    else:
        neigh_pixs += eps
        out_pixel = np.sum(neigh_pixs**(Q+1)) / (np.sum(neigh_pixs**(Q))+eps)
    return out_pixel
def contraharmonic_mean_filter(image,filter_size,Q):
    filtered_image = np.zeros(list(image.shape))
    x,y = image.shape
#     count = 0
    for i in range(x):
        for j in range(y):
            filtered_image[i,j] = pix_contraharmonic_mean_filter([i,j], image, filter_size,Q)
    fil_size = filter_size
    return(filtered_image, fil_size)

# %% [markdown]
# # a

# %%
ar_image1,s1 = arithmetic_mean_filter(image,3)
ar_image2,s2 = arithmetic_mean_filter(image,7)

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(ar_image1.astype(np.uint8),'gray')
plt.title('Artihmetic mean (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(ar_image2.astype(np.uint8),'gray')
plt.title('Artihmetic mean (size = 7)')
plt.axis('off')
plt.show()

# %% [markdown]
# # b

# %%
ge_image1,s1 = geometric_mean_filter(image,3)
ge_image2,s2 = geometric_mean_filter(image,7)

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(ge_image1,'gray',vmin = 0, vmax = 255)
plt.title('geometric mean (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(ge_image2,'gray',vmin = 0, vmax = 255)
plt.title('geometric mean (size = 7)')
plt.axis('off')
plt.show()

# %% [markdown]
# # c

# %%
ha_image1,s1 = harmonic_mean_filter(image,3)
ha_image2,s2 = harmonic_mean_filter(image,7)
# Out:
# C:\Users\sherw\Anaconda3\lib\statistics.py:406: RuntimeWarning: divide by zero encountered in true_divide
#   T, total, count = _sum(1/x for x in _fail_neg(data, errmsg))

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(ha_image1,'gray',vmin = 0, vmax = 255)
plt.title('harmonic mean (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(ha_image2,'gray',vmin = 0, vmax = 255)
plt.title('harmonic mean (size = 7)')
plt.axis('off')
plt.show()

# %% [markdown]
# # d

# %%
cha_image1,s1 = contraharmonic_mean_filter(image,3,1.5)
cha_image2,s2 = contraharmonic_mean_filter(image,7,1.5)

# %%
plt.suptitle('Q = 1.5')
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(cha_image1,'gray',vmin = 0, vmax = 255)
plt.title('contraharmonic mean (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(cha_image2,'gray',vmin = 0, vmax = 255)
plt.title('contraharmonic mean (size = 7)')
plt.axis('off')
plt.show()

# %%
cha_image1,s1 = contraharmonic_mean_filter(image,3,-1.5)
cha_image2,s2 = contraharmonic_mean_filter(image,7,-1.5)

# %%
plt.suptitle('Q = -1.5')
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(cha_image1,'gray',vmin = 0, vmax = 255)
plt.title('contraharmonic mean (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(cha_image2,'gray',vmin = 0, vmax = 255)
plt.title('contraharmonic mean (size = 7)')
plt.axis('off')
plt.show()

# %% [markdown]
# # e

# %%
mid_image1,s1 = midpoint_filter(image,3)
mid_image2,s2 = midpoint_filter(image,7)
mid_image3,s3 = midpoint_filter(image,9)
# Out:
# C:\Users\sherw\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in ubyte_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,4,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,4,2)
plt.imshow(mid_image1,'gray',vmin = 0, vmax = 255)
plt.title('midpoint (size = 3)')
plt.axis('off')
plt.subplot(1,4,3)
plt.imshow(mid_image2,'gray',vmin = 0, vmax = 255)
plt.title('midpoint (size = 7)')
plt.axis('off')
plt.subplot(1,4,4)
plt.imshow(mid_image3,'gray',vmin = 0, vmax = 255)
plt.title('midpoint (size = 9)')
plt.axis('off')
plt.show()

# %% [markdown]
# # f

# %%
med_image1,s1 = median_filter(image,3)
med_image2,s2 = median_filter(image,7)
med_image3,s3 = median_filter(image,9)

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,4,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,4,2)
plt.imshow(med_image1,'gray',vmin = 0, vmax = 255)
plt.title('median (size = 3)')
plt.axis('off')
plt.subplot(1,4,3)
plt.imshow(med_image2,'gray',vmin = 0, vmax = 255)
plt.title('median (size = 7)')
plt.axis('off')
plt.subplot(1,4,4)
plt.imshow(med_image3,'gray',vmin = 0, vmax = 255)
plt.title('median (size = 9)')
plt.axis('off')
plt.show()

# %% [markdown]
# # g

# %%
min_image1,s1 = min_filter(image,3)
min_image2,s2 = min_filter(image,9)

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(min_image1,'gray',vmin = 0, vmax = 255)
plt.title('min (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(min_image2,'gray',vmin = 0, vmax = 255)
plt.title('min (size = 9)')
plt.axis('off')
plt.show()

# %% [markdown]
# # h

# %%
max_image1,s1 = max_filter(image,3)
max_image2,s2 = max_filter(image,9)

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.subplot(1,3,1)
plt.imshow(image,'gray')
plt.title('original')
plt.axis('off')
plt.subplot(1,3,2)
plt.imshow(max_image1,'gray',vmin = 0, vmax = 255)
plt.title('max (size = 3)')
plt.axis('off')
plt.subplot(1,3,3)
plt.imshow(max_image2,'gray',vmin = 0, vmax = 255)
plt.title('max (size = 9)')
plt.axis('off')
plt.show()
